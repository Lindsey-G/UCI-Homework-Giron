# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')
from config import pg_password
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-424f4b7cce47> in <module>
#       4 import warnings
#       5 warnings.filterwarnings('ignore')
# ----> 6 from config import pg_password
#
# ModuleNotFoundError: No module named 'config'

# %% [markdown]
# ## Reading in CSV files into DataFrames

# %%
# Create path to csv 
fixed_telephone = "fixed_telephone_subcriptions/API.csv"
mobile_cellular = "mobile_cellular_subcriptions/mobile_cellular.csv"

# %%
# Create variable using .read_csv in from path
fixed_df = pd.read_csv(fixed_telephone)
mobile_df = pd.read_csv(mobile_cellular)

# %%
# Display fixed_df 
fixed_df.head()
# Out:
#   Country Name Country Code                 Indicator Name Indicator Code  \
# 0        Aruba          ABW  Fixed telephone subscriptions    IT.MLT.MAIN
# 1  Afghanistan          AFG  Fixed telephone subscriptions    IT.MLT.MAIN
# 2       Angola          AGO  Fixed telephone subscriptions    IT.MLT.MAIN
# 3      Albania          ALB  Fixed telephone subscriptions    IT.MLT.MAIN
# 4      Andorra          AND  Fixed telephone subscriptions    IT.MLT.MAIN
#
#      1960  1961  1962  1963  1964     1965  ...      2011      2012      2013  \
# 0     NaN   NaN   NaN   NaN   NaN      NaN  ...       NaN   36000.0   35000.0
# 1  7700.0   NaN   NaN   NaN   NaN   9300.0  ...   13509.0   90017.0   95769.0
# 2  6666.0   NaN   NaN   NaN   NaN  10000.0  ...  159485.0  208345.0  214950.0
# 3  6845.0   NaN   NaN   NaN   NaN  13991.0  ...  338844.0  312000.0  281200.0
# 4     NaN   NaN   NaN   NaN   NaN    500.0  ...   38401.0   38320.0   38572.0
#
#        2014      2015      2016      2017      2018      2019  2020
# 0   35000.0   35000.0       NaN       NaN       NaN       NaN   NaN
# 1  101931.0  110000.0  114192.0  118769.0  127794.0  134636.0   NaN
# 2  287416.0  284925.0  304493.0  161070.0  171858.0  124726.0   NaN
# 3  235734.0  226718.0  248640.0  246720.0  248631.0  242859.0   NaN
# 4   38237.0   38850.0   38694.0   38411.0   39375.0   39657.0   NaN
#
# [5 rows x 65 columns]

# %%
# Display mobile_df
mobile_df.head()
# Out:
#   Country Name Country Code                 Indicator Name Indicator Code  \
# 0        Aruba          ABW  Mobile cellular subscriptions    IT.CEL.SETS
# 1  Afghanistan          AFG  Mobile cellular subscriptions    IT.CEL.SETS
# 2       Angola          AGO  Mobile cellular subscriptions    IT.CEL.SETS
# 3      Albania          ALB  Mobile cellular subscriptions    IT.CEL.SETS
# 4      Andorra          AND  Mobile cellular subscriptions    IT.CEL.SETS
#
#    1960  1961  1962  1963  1964  1965  ...        2011        2012  \
# 0   0.0   NaN   NaN   NaN   NaN   0.0  ...         NaN    135000.0
# 1   0.0   NaN   NaN   NaN   NaN   0.0  ...  13797879.0  15340115.0
# 2   0.0   NaN   NaN   NaN   NaN   0.0  ...  12073218.0  12785109.0
# 3   0.0   NaN   NaN   NaN   NaN   0.0  ...   3100000.0   3500000.0
# 4   0.0   NaN   NaN   NaN   NaN   0.0  ...     65044.0     63865.0
#
#          2013        2014        2015        2016        2017        2018  \
# 0    138800.0    139700.0    141000.0         NaN         NaN         NaN
# 1  16807156.0  18407168.0  19709038.0  21602982.0  23929713.0  21976355.0
# 2  13285198.0  14052558.0  13884532.0  13001124.0  13323952.0  13288421.0
# 3   3685983.0   3359654.0   3400955.0   3369756.0   3625699.0   2714878.0
# 4     63931.0     66241.0     71336.0     76132.0     80337.0     82614.0
#
#          2019  2020
# 0         NaN   NaN
# 1  22580071.0   NaN
# 2  14830154.0   NaN
# 3   2630076.0   NaN
# 4     87909.0   NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Cleaning DataFrames

# %%
# Using .loc to pull only USA data for usa_fixed_df
usa_fixed_df = fixed_df.loc[fixed_df["Country Code"] == "USA"]
usa_fixed_df
# Out:
#       Country Name Country Code                 Indicator Name Indicator Code  \
# 249  United States          USA  Fixed telephone subscriptions    IT.MLT.MAIN
#
#            1960  1961  1962  1963  1964        1965  ...         2011  \
# 249  49269000.0   NaN   NaN   NaN   NaN  58289000.0  ...  143319000.0
#
#             2012         2013         2014         2015         2016  \
# 249  138595000.0  133233000.0  128495000.0  124848000.0  121343000.0
#
#             2017         2018         2019  2020
# 249  116297000.0  110439000.0  107281000.0   NaN
#
# [1 rows x 65 columns]

# %%
# Using drop() along with .loc to drop columns from 1960 to 2004 data for usa_fixed_df
usa_fixed_df.drop(usa_fixed_df.iloc[:, 4:49], inplace = True, axis = 1)
usa_fixed_df
# Out:
#       Country Name Country Code                 Indicator Name Indicator Code  \
# 249  United States          USA  Fixed telephone subscriptions    IT.MLT.MAIN
#
#             2005         2006         2007         2008         2009  \
# 249  175160940.0  167459899.0  158418151.0  162763000.0  152873000.0
#
#             2010         2011         2012         2013         2014  \
# 249  149652000.0  143319000.0  138595000.0  133233000.0  128495000.0
#
#             2015         2016         2017         2018         2019  2020
# 249  124848000.0  121343000.0  116297000.0  110439000.0  107281000.0   NaN

# %%
# Using .loc to pull only USA data for usa_mobile_df
usa_mobile_df = mobile_df[mobile_df["Country Code"] == "USA"]
usa_mobile_df
# Out:
#       Country Name Country Code                 Indicator Name Indicator Code  \
# 249  United States          USA  Mobile cellular subscriptions    IT.CEL.SETS
#
#      1960  1961  1962  1963  1964  1965  ...         2011         2012  \
# 249   0.0   NaN   NaN   NaN   NaN   0.0  ...  297404000.0  304838000.0
#
#             2013         2014         2015         2016         2017  \
# 249  310698000.0  355500000.0  382307000.0  396000000.0  400000000.0
#
#             2018  2019  2020
# 249  422000000.0   NaN   NaN
#
# [1 rows x 65 columns]

# %%
# Using drop() along with .loc to drop columns from 1960 to 2004 data for usa_mobile_df
usa_mobile_df.drop(usa_mobile_df.iloc[:, 4:49], inplace = True, axis = 1)
usa_mobile_df
# Out:
#       Country Name Country Code                 Indicator Name Indicator Code  \
# 249  United States          USA  Mobile cellular subscriptions    IT.CEL.SETS
#
#             2005         2006         2007         2008         2009  \
# 249  203700000.0  229600000.0  249300000.0  261300000.0  274283000.0
#
#             2010         2011         2012         2013         2014  \
# 249  285118000.0  297404000.0  304838000.0  310698000.0  355500000.0
#
#             2015         2016         2017         2018  2019  2020
# 249  382307000.0  396000000.0  400000000.0  422000000.0   NaN   NaN

# %% [markdown]
# ## Merging both Dataframes

# %%
# Merge both DataFrames on "Country Name", make sure to use suffixes to lable columns
merged_df = pd.merge(usa_fixed_df, usa_mobile_df, on="Country Name", suffixes=("Fixed Cellular","Mobile Cellular"))
merged_df
# Out:
#     Country Name Country CodeFixed Cellular   Indicator NameFixed Cellular  \
# 0  United States                        USA  Fixed telephone subscriptions
#
#   Indicator CodeFixed Cellular  2005Fixed Cellular  2006Fixed Cellular  \
# 0                  IT.MLT.MAIN         175160940.0         167459899.0
#
#    2007Fixed Cellular  2008Fixed Cellular  2009Fixed Cellular  \
# 0         158418151.0         162763000.0         152873000.0
#
#    2010Fixed Cellular  ...  2011Mobile Cellular  2012Mobile Cellular  \
# 0         149652000.0  ...          297404000.0          304838000.0
#
#    2013Mobile Cellular  2014Mobile Cellular  2015Mobile Cellular  \
# 0          310698000.0          355500000.0          382307000.0
#
#    2016Mobile Cellular  2017Mobile Cellular  2018Mobile Cellular  \
# 0          396000000.0          400000000.0          422000000.0
#
#    2019Mobile Cellular  2020Mobile Cellular
# 0                  NaN                  NaN
#
# [1 rows x 39 columns]

# %%
# Using list on columns to clarify how name is displayed. This helped us solve our column name issue.
list(merged_df.columns)
# Out:
# ['Country Name',
#  'Country CodeFixed Cellular',
#  'Indicator NameFixed Cellular',
#  'Indicator CodeFixed Cellular',
#  '2005Fixed Cellular',
#  '2006Fixed Cellular',
#  '2007Fixed Cellular',
#  '2008Fixed Cellular',
#  '2009Fixed Cellular',
#  '2010Fixed Cellular',
#  '2011Fixed Cellular',
#  '2012Fixed Cellular',
#  '2013Fixed Cellular',
#  '2014Fixed Cellular',
#  '2015Fixed Cellular',
#  '2016Fixed Cellular',
#  '2017Fixed Cellular',
#  '2018Fixed Cellular',
#  '2019Fixed Cellular',
#  '2020Fixed Cellular',
#  'Country CodeMobile Cellular',
#  'Indicator NameMobile Cellular',
#  'Indicator CodeMobile Cellular',
#  '2005Mobile Cellular',
#  '2006Mobile Cellular',
#  '2007Mobile Cellular',
#  '2008Mobile Cellular',
#  '2009Mobile Cellular',
#  '2010Mobile Cellular',
#  '2011Mobile Cellular',
#  '2012Mobile Cellular',
#  '2013Mobile Cellular',
#  '2014Mobile Cellular',
#  '2015Mobile Cellular',
#  '2016Mobile Cellular',
#  '2017Mobile Cellular',
#  '2018Mobile Cellular',
#  '2019Mobile Cellular',
#  '2020Mobile Cellular']

# %% [markdown]
# ## Transforming Tables

# %%
# Create a variable for "Country Name", "Fixed Cellular", and "Mobile Cellular" from 2005 - 2009
year_2005_2009_cols = ["Country Name", "2005Fixed Cellular", "2006Fixed Cellular", "2007Fixed Cellular", "2008Fixed Cellular", "2009Fixed Cellular", "2005Mobile Cellular", "2006Mobile Cellular", "2007Mobile Cellular", "2008Mobile Cellular", "2009Mobile Cellular"]
# Create Dataframe for only 2005-2009 data with .copy()
year_2005_2009 = merged_df[year_2005_2009_cols].copy()
# Dispay to confirm data
year_2005_2009.set_index("Country Name")
# Out:
#                2005Fixed Cellular  2006Fixed Cellular  2007Fixed Cellular  \
# Country Name
# United States         175160940.0         167459899.0         158418151.0
#
#                2008Fixed Cellular  2009Fixed Cellular  2005Mobile Cellular  \
# Country Name
# United States         162763000.0         152873000.0          203700000.0
#
#                2006Mobile Cellular  2007Mobile Cellular  2008Mobile Cellular  \
# Country Name
# United States          229600000.0          249300000.0          261300000.0
#
#                2009Mobile Cellular
# Country Name
# United States          274283000.0

# %%
# Create a variable for "Country Name", "Fixed Cellular", and "Mobile Cellular" from 2010 - 2014
year_2010_2014_cols = ["Country Name", "2010Fixed Cellular", "2011Fixed Cellular", "2012Fixed Cellular", "2013Fixed Cellular", "2014Fixed Cellular", "2010Mobile Cellular", "2011Mobile Cellular", "2012Mobile Cellular", "2013Mobile Cellular", "2014Mobile Cellular"]
# Create Dataframe for only 2010-2014 data with .copy()
year_2010_2014 = merged_df[year_2010_2014_cols].copy()
# Dispay to confirm data
year_2010_2014
# Out:
#     Country Name  2010Fixed Cellular  2011Fixed Cellular  2012Fixed Cellular  \
# 0  United States         149652000.0         143319000.0         138595000.0
#
#    2013Fixed Cellular  2014Fixed Cellular  2010Mobile Cellular  \
# 0         133233000.0         128495000.0          285118000.0
#
#    2011Mobile Cellular  2012Mobile Cellular  2013Mobile Cellular  \
# 0          297404000.0          304838000.0          310698000.0
#
#    2014Mobile Cellular
# 0          355500000.0

# %%
# Create a variable for "Country Name", "Fixed Cellular", and "Mobile Cellular" from 2015 - 2018
year_2015_2018_cols = ["Country Name", "2015Fixed Cellular", "2016Fixed Cellular", "2017Fixed Cellular", "2018Fixed Cellular", "2015Mobile Cellular", "2016Mobile Cellular", "2017Mobile Cellular", "2018Mobile Cellular"]
# Create Dataframe for only 2015-2018 data with .copy()
year_2015_2018 = merged_df[year_2015_2018_cols].copy()
# Dispay to confirm data
year_2015_2018
# Out:
#     Country Name  2015Fixed Cellular  2016Fixed Cellular  2017Fixed Cellular  \
# 0  United States         124848000.0         121343000.0         116297000.0
#
#    2018Fixed Cellular  2015Mobile Cellular  2016Mobile Cellular  \
# 0         110439000.0          382307000.0          396000000.0
#
#    2017Mobile Cellular  2018Mobile Cellular
# 0          400000000.0          422000000.0

# %% [markdown]
# ## Load data to Postgresql

# %%
# Make connection to telecommunication_db in postgresql
connection_string = "postgres:{pg_password}@localhost:5432/telecommunication_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Display table_names() from telecommunication_db
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-9d4eba319dec> in <module>
#       1 # Display table_names() from telecommunication_db
# ----> 2 engine.table_names()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2314         """
#    2315
# -> 2316         with self._optional_conn_ctx_manager(connection) as conn:
#    2317             return self.dialect.get_table_names(conn, schema)
#    2318
#
# ~\anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2084     def _optional_conn_ctx_manager(self, connection=None):
#    2085         if connection is None:
# -> 2086             with self._contextual_connect() as conn:
#    2087                 yield conn
#    2088         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# load year_2005_2009 DataFrame to postgresql
year_2005_2009.to_sql(name='year_2005_2009', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedColumn: column "index" of relation "year_2005_2009" does not exist
# LINE 1: INSERT INTO year_2005_2009 (index, "Country Name", "2005Fixe...
#                                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-15-5aca9b7b417a> in <module>
#       1 # load year_2005_2009 DataFrame to postgresql
# ----> 2 year_2005_2009.to_sql(name='year_2005_2009', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2600         from pandas.io import sql
#    2601
# -> 2602         sql.to_sql(
#    2603             self,
#    2604             name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "index" of relation "year_2005_2009" does not exist
# LINE 1: INSERT INTO year_2005_2009 (index, "Country Name", "2005Fixe...
#                                     ^
#
# [SQL: INSERT INTO year_2005_2009 (index, "Country Name", "2005Fixed Cellular", "2006Fixed Cellular", "2007Fixed Cellular", "2008Fixed Cellular", "2009Fixed Cellular", "2005Mobile Cellular", "2006Mobile Cellular", "2007Mobile Cellular", "2008Mobile Cellular", "2009Mobile Cellular") VALUES (%(index)s, %(Country Name)s, %(2005Fixed Cellular)s, %(2006Fixed Cellular)s, %(2007Fixed Cellular)s, %(2008Fixed Cellular)s, %(2009Fixed Cellular)s, %(2005Mobile Cellular)s, %(2006Mobile Cellular)s, %(2007Mobile Cellular)s, %(2008Mobile Cellular)s, %(2009Mobile Cellular)s)]
# [parameters: {'index': 0, 'Country Name': 'United States', '2005Fixed Cellular': 175160940.0, '2006Fixed Cellular': 167459899.0, '2007Fixed Cellular': 158418151.0, '2008Fixed Cellular': 162763000.0, '2009Fixed Cellular': 152873000.0, '2005Mobile Cellular': 203700000.0, '2006Mobile Cellular': 229600000.0, '2007Mobile Cellular': 249300000.0, '2008Mobile Cellular': 261300000.0, '2009Mobile Cellular': 274283000.0}]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
# load year_2010_2014 DataFrame to postgresql
year_2010_2014.to_sql(name='year_2010_2014', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedColumn: column "index" of relation "year_2010_2014" does not exist
# LINE 1: INSERT INTO year_2010_2014 (index, "Country Name", "2010Fixe...
#                                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-37-15abca9aaf80> in <module>
#       1 # load year_2010_2014 DataFrame to postgresql
# ----> 2 year_2010_2014.to_sql(name='year_2010_2014', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2600         from pandas.io import sql
#    2601
# -> 2602         sql.to_sql(
#    2603             self,
#    2604             name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "index" of relation "year_2010_2014" does not exist
# LINE 1: INSERT INTO year_2010_2014 (index, "Country Name", "2010Fixe...
#                                     ^
#
# [SQL: INSERT INTO year_2010_2014 (index, "Country Name", "2010Fixed Cellular", "2011Fixed Cellular", "2012Fixed Cellular", "2013Fixed Cellular", "2014Fixed Cellular", "2010Mobile Cellular", "2011Mobile Cellular", "2012Mobile Cellular", "2013Mobile Cellular", "2014Mobile Cellular") VALUES (%(index)s, %(Country Name)s, %(2010Fixed Cellular)s, %(2011Fixed Cellular)s, %(2012Fixed Cellular)s, %(2013Fixed Cellular)s, %(2014Fixed Cellular)s, %(2010Mobile Cellular)s, %(2011Mobile Cellular)s, %(2012Mobile Cellular)s, %(2013Mobile Cellular)s, %(2014Mobile Cellular)s)]
# [parameters: {'index': 0, 'Country Name': 'United States', '2010Fixed Cellular': 149652000.0, '2011Fixed Cellular': 143319000.0, '2012Fixed Cellular': 138595000.0, '2013Fixed Cellular': 133233000.0, '2014Fixed Cellular': 128495000.0, '2010Mobile Cellular': 285118000.0, '2011Mobile Cellular': 297404000.0, '2012Mobile Cellular': 304838000.0, '2013Mobile Cellular': 310698000.0, '2014Mobile Cellular': 355500000.0}]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
# load year_2015_2018 DataFrame to postgresql
year_2015_2018.to_sql(name='year_2015_2018', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# UndefinedColumn: column "index" of relation "year_2015_2018" does not exist
# LINE 1: INSERT INTO year_2015_2018 (index, "Country Name", "2015Fixe...
#                                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-38-3cbcb2162460> in <module>
#       1 # load year_2015_2018 DataFrame to postgresql
# ----> 2 year_2015_2018.to_sql(name='year_2015_2018', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2600         from pandas.io import sql
#    2601
# -> 2602         sql.to_sql(
#    2603             self,
#    2604             name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "index" of relation "year_2015_2018" does not exist
# LINE 1: INSERT INTO year_2015_2018 (index, "Country Name", "2015Fixe...
#                                     ^
#
# [SQL: INSERT INTO year_2015_2018 (index, "Country Name", "2015Fixed Cellular", "2016Fixed Cellular", "2017Fixed Cellular", "2018Fixed Cellular", "2015Mobile Cellular", "2016Mobile Cellular", "2017Mobile Cellular", "2018Mobile Cellular") VALUES (%(index)s, %(Country Name)s, %(2015Fixed Cellular)s, %(2016Fixed Cellular)s, %(2017Fixed Cellular)s, %(2018Fixed Cellular)s, %(2015Mobile Cellular)s, %(2016Mobile Cellular)s, %(2017Mobile Cellular)s, %(2018Mobile Cellular)s)]
# [parameters: {'index': 0, 'Country Name': 'United States', '2015Fixed Cellular': 124848000.0, '2016Fixed Cellular': 121343000.0, '2017Fixed Cellular': 116297000.0, '2018Fixed Cellular': 110439000.0, '2015Mobile Cellular': 382307000.0, '2016Mobile Cellular': 396000000.0, '2017Mobile Cellular': 400000000.0, '2018Mobile Cellular': 422000000.0}]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %% [markdown]
# ## Read in tables from Postgresql

# %%
# Read in year_2005_2009 table from postgresql
pd.read_sql_query('SELECT * FROM year_2005_2009', con=engine)
# Out:
# Empty DataFrame
# Columns: [id, Country Name, 2005Fixed Cellular, 2006Fixed Cellular, 2007Fixed Cellular, 2008Fixed Cellular, 2009Fixed Cellular, 2005Mobile Cellular, 2006Mobile Cellular, 2007Mobile Cellular, 2008Mobile Cellular, 2009Mobile Cellular]
# Index: []

# %%
# Read in year_2010_2014 table from postgresql
pd.read_sql_query('SELECT * FROM year_2010_2014', con=engine)
# Out:
# Empty DataFrame
# Columns: [id, country_name, 2010Fixed Cellular, 2011Fixed Cellular, 2012Fixed Cellular, 2013Fixed Cellular, 2014Fixed Cellular, 2010Mobile Cellular, 2011Mobile Cellular, 2012Mobile Cellular, 2013Mobile Cellular, 2014Mobile Cellular]
# Index: []

# %%
# Read in year_2015_2018 table from postgresql
pd.read_sql_query('SELECT * FROM year_2015_2018', con=engine)
# Out:
# Empty DataFrame
# Columns: [id, country_name, 2015Fixed Cellular, 2016Fixed Cellular, 2017Fixed Cellular, 2018Fixed Cellular, 2015Mobile Cellular, 2016Mobile Cellular, 2017Mobile Cellular, 2018Mobile Cellular]
# Index: []
